# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import numpy as np
import tensorflow as tf
import keras

from helpers.image import get_image, generate_random_image
from helpers.model import get_vgg_model, get_features_from_model

from config import CONTENT_LAYER, STYLE_LAYERS
# Out:
# Using TensorFlow backend.

# %%
# Define our image paths and load the images
content_path = '../data/turtle.png'
style_path = '../data/van-gogh.jpg'

content_image = get_image(content_path, show=True)
style_image = get_image(style_path, show=True)
generated_image = generate_random_image(show=True)

print(content_image.shape)
print(style_image.shape)
print(generated_image.shape)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (1, 512, 512, 3)
# (1, 512, 512, 3)
# (1, 512, 512, 3)

# %%
sess = tf.InteractiveSession()

# %%
content_model = get_vgg_model(output_layer=CONTENT_LAYER)
generated_model = get_vgg_model()
style_models = [get_vgg_model(output_layer=style_layer) for style_layer,co_eff in STYLE_LAYERS]
